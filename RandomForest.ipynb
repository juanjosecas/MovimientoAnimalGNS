# %% [markdown]
# # Análisis con Random Forest
#
# Este notebook implementará un modelo de Random Forest para clasificación o regresión.
#
# ## Pasos a implementar:
#
# - Cargar librerías para carga y análisis de datos
# - Cargar y combinar archivos CSV con las coordenadas del ratón
# - Descartar los primeros 9500 frames de cada archivo para omitir la habituación
# - Calcular características y métricas relevantes
# - Entrenar el modelo Random Forest

# %%
# TODO: Implementar este notebook
